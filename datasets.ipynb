# %%
import pandas as pd 
from preprocessing.data_cleanse import limpiar_dataset
from preprocessing.hmv import hmv_dataset
from preprocessing.df_to_numeric import df_to_numeric

# %%
df = pd.read_csv('data/raw/pf_suvs_i302_1s2025.csv')

# split train and test 80/20
train_complete = df.sample(frac=0.8, random_state=42)
test = df.drop(train_complete.index)

#from train complete split into train and validation 80/20
train = train_complete.sample(frac=0.8, random_state=42)
val = train_complete.drop(train.index)

train.to_csv('data/raw/train.csv', index=False)
val.to_csv('data/raw/val.csv', index=False)
test.to_csv('data/raw/test.csv', index=False)

# %%
train = limpiar_dataset(train)
train = hmv_dataset(train, train)
train.to_csv('data/processed/train_processed.csv', index=False)
val = limpiar_dataset(val)
val = hmv_dataset(train, val)
val.to_csv('data/processed/val_processed.csv', index=False)
test = limpiar_dataset(test)
test = hmv_dataset(train, test)
test.to_csv('data/processed/test_processed.csv', index=False)
# Out:
# [TOTAL] Muestras eliminadas en total: 0
#
# ✔️ Marcas imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Modelos imputados: 1
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Muestras version train imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#    ➤ Versiones imputadas: 0
#    ➤ Muestras eliminadas por no poder imputar: 0
#
# 🗑️ Paso 2 terminado: Eliminadas 114 filas con versiones inválidas no corregibles.
# [hmv_version] Muestras eliminadas: 114
#
# ✔️ Imputaciones Combustible realizadas: 0
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de puertas realizadas: 240
# 🗑️ Muestras eliminadas: 2
# [hmv_puertas] Muestras eliminadas: 2
#
# ✔️ Imputaciones de transmision realizadas: 2580
# 🗑️ Muestras eliminadas: 326
# [hmv_transmision] Muestras eliminadas: 326
#
# ✔️ Imputaciones de motor realizadas: 44
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de camara realizadas por coincidencia exacta: 6209
# 🔧 Muestras sin coincidencias (asignadas 0): 2146
#
# ✔️ Imputaciones HP realizadas: 8047
# 🗑️ Muestras eliminadas: 23
# [hmv_hp] Muestras eliminadas: 23
#
# ✔️ Imputaciones traccion realizadas por coincidencia: 4014
# 🔧 Asignaciones por defecto ('4x2'): 2938
#
# ✔️ Años imputados sin leakage: 1
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 📊 Estadísticas finales KM:
# 🔍 Total de valores marcados como outliers: 770
# 🛠️ Total de valores imputados exitosamente: 770
# 🚫 Total de valores que quedaron como NaN: 0
# ✅ Imputaciones  vendedor completadas: 0 valores reemplazados.
#
#
# ✅ Total de colores imputados por contexto: 241
#
# 🔍 Paso 3: Agrupando colores por tokens similares...
#
# 📦 Grupos de colores formados: 27
# 🔗 Token base: 'azul' → ['Azul', 'Azul claro']
# 🔗 Token base: 'gris' → ['GRIS ARTENSE', 'GRIS LAQUE', 'GRIS PLATA', 'GRIS PLATINO', 'GRIS SELENIUM', 'GRIS SILVERSTONE', 'GRIS TITANE', 'Gris', 'Gris oscuro', 'Gris plata']
# 🔗 Token base: 'negro' → ['NEGRA', 'Negra', 'Negro']
# 🔗 Token base: 'amarillo' → ['Amarillo']
# 🔗 Token base: 'blanco' → ['BLACK MEET KETTLE', 'BLANCA', 'BLANCO BANCHISA BICOLOR NEGRO', 'BLANCO GLACIAR', 'BLANCO NACRE TRICAPA', 'Blanca', 'Blanco', 'Blanco Glaciar', 'blanca']
# 🔗 Token base: 'rojo' → ['ROJO SUNSET METALIZADO', 'Rojo']
# 🔗 Token base: 'plateado' → ['Plateado']
# 🔗 Token base: 'celeste' → ['Celeste']
# 🔗 Token base: 'verde' → ['Verde', 'Verde oscuro']
# 🔗 Token base: 'dorado' → ['Dorado']
# 🔗 Token base: 'marron' → ['MARRON KODIAK', 'Marrón', 'Marrón claro', 'Marrón oscuro']
# 🔗 Token base: 'naranja' → ['Naranja']
# 🔗 Token base: 'beige' → ['Beige', 'Beige techo negro']
# 🔗 Token base: 'mineralweiss' → ['MINERALWEISS METALLIC']
# 🔗 Token base: 'summit' → ['SUMMIT WHITE']
# 🔗 Token base: 'violeta' → ['Violeta', 'violeta']
# 🔗 Token base: 'cafe' → ['Café']
# 🔗 Token base: 'bordo' → ['Bordó']
# 🔗 Token base: 'otro' → ['Otro']
# 🔗 Token base: 'prata' → ['PLATA BARI', 'PRATA BARI+TET VULC', 'Plata']
# 🔗 Token base: 'blue' → ['blue']
# 🔗 Token base: 'steelblue' → ['steel_blue']
# 🔗 Token base: 'acero' → ['Acero']
# 🔗 Token base: 'rosa' → ['Rosa']
# 🔗 Token base: 'carbon' → ['CARBON BLACK']
# 🔗 Token base: 'skyscraper' → ['SKYSCRAPER GRAU METALLIC']
# 🔗 Token base: 'grafito' → ['Grafito']
#
# ✅ Total de colores imputados por contexto: 230
#
# 📚 Aprendiendo colores limpios desde df_train...
#
# [TOTAL] Muestras eliminadas en total: 465
# [TOTAL] Muestras eliminadas en total: 0
#
# ✔️ Marcas imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Modelos imputados: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Muestras version train imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#    ➤ Versiones imputadas: 0
#    ➤ Muestras eliminadas por no poder imputar: 0
#
# 🗑️ Paso 2 terminado: Eliminadas 149 filas con versiones inválidas no corregibles.
# [hmv_version] Muestras eliminadas: 149
#
# ✔️ Imputaciones Combustible realizadas: 0
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de puertas realizadas: 64
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de transmision realizadas: 643
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de motor realizadas: 12
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de camara realizadas por coincidencia exacta: 1981
# 🔧 Muestras sin coincidencias (asignadas 0): 79
#
# ✔️ Imputaciones HP realizadas: 1996
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones traccion realizadas por coincidencia: 1748
# 🔧 Asignaciones por defecto ('4x2'): 0
#
# ✔️ Años imputados sin leakage: 0
#
# 📊 Estadísticas finales KM:
# 🔍 Total de valores marcados como outliers: 351
# 🛠️ Total de valores imputados exitosamente: 351
# 🚫 Total de valores que quedaron como NaN: 0
# ✅ Imputaciones  vendedor completadas: 0 valores reemplazados.
#
#
# ✅ Total de colores imputados por contexto: 0
#
# 🔍 Paso 3: Agrupando colores por tokens similares...
#
# 📦 Grupos de colores formados: 27
# 🔗 Token base: 'azul' → ['azul']
# 🔗 Token base: 'gris' → ['gris']
# 🔗 Token base: 'negro' → ['negro']
# 🔗 Token base: 'amarillo' → ['amarillo']
# 🔗 Token base: 'blanco' → ['blanco']
# 🔗 Token base: 'rojo' → ['rojo']
# 🔗 Token base: 'plateado' → ['plateado']
# 🔗 Token base: 'celeste' → ['celeste']
# 🔗 Token base: 'verde' → ['verde']
# 🔗 Token base: 'dorado' → ['dorado']
# 🔗 Token base: 'marron' → ['marron']
# 🔗 Token base: 'naranja' → ['naranja']
# 🔗 Token base: 'beige' → ['beige']
# 🔗 Token base: 'mineralweiss' → ['mineralweiss']
# 🔗 Token base: 'summit' → ['summit']
# 🔗 Token base: 'violeta' → ['violeta']
# 🔗 Token base: 'cafe' → ['cafe']
# 🔗 Token base: 'bordo' → ['bordo']
# 🔗 Token base: 'otro' → ['otro']
# 🔗 Token base: 'prata' → ['prata']
# 🔗 Token base: 'blue' → ['blue']
# 🔗 Token base: 'steelblue' → ['steelblue']
# 🔗 Token base: 'acero' → ['acero']
# 🔗 Token base: 'rosa' → ['rosa']
# 🔗 Token base: 'carbon' → ['carbon']
# 🔗 Token base: 'skyscraper' → ['skyscraper']
# 🔗 Token base: 'grafito' → ['grafito']
#
# ✅ Total de colores imputados por contexto: 58
#
# 📚 Aprendiendo colores limpios desde df_train...
#
# [TOTAL] Muestras eliminadas en total: 149
# [TOTAL] Muestras eliminadas en total: 0
#
# ✔️ Marcas imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Modelos imputados: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#
# ✔️ Muestras version train imputadas: 0
# 🗑️ Muestras eliminadas por no poder imputar: 0
#    ➤ Versiones imputadas: 0
#    ➤ Muestras eliminadas por no poder imputar: 0
#
# 🗑️ Paso 2 terminado: Eliminadas 180 filas con versiones inválidas no corregibles.
# [hmv_version] Muestras eliminadas: 180
#
# ✔️ Imputaciones Combustible realizadas: 0
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de puertas realizadas: 86
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de transmision realizadas: 798
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de motor realizadas: 10
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones de camara realizadas por coincidencia exacta: 2473
# 🔧 Muestras sin coincidencias (asignadas 0): 76
#
# ✔️ Imputaciones HP realizadas: 2474
# 🗑️ Muestras eliminadas: 0
#
# ✔️ Imputaciones traccion realizadas por coincidencia: 2158
# 🔧 Asignaciones por defecto ('4x2'): 0
#
# ✔️ Años imputados sin leakage: 0
#
# 📊 Estadísticas finales KM:
# 🔍 Total de valores marcados como outliers: 428
# 🛠️ Total de valores imputados exitosamente: 428
# 🚫 Total de valores que quedaron como NaN: 0
# ✅ Imputaciones  vendedor completadas: 0 valores reemplazados.
#
#
# ✅ Total de colores imputados por contexto: 0
#
# 🔍 Paso 3: Agrupando colores por tokens similares...
#
# 📦 Grupos de colores formados: 27
# 🔗 Token base: 'azul' → ['azul']
# 🔗 Token base: 'gris' → ['gris']
# 🔗 Token base: 'negro' → ['negro']
# 🔗 Token base: 'amarillo' → ['amarillo']
# 🔗 Token base: 'blanco' → ['blanco']
# 🔗 Token base: 'rojo' → ['rojo']
# 🔗 Token base: 'plateado' → ['plateado']
# 🔗 Token base: 'celeste' → ['celeste']
# 🔗 Token base: 'verde' → ['verde']
# 🔗 Token base: 'dorado' → ['dorado']
# 🔗 Token base: 'marron' → ['marron']
# 🔗 Token base: 'naranja' → ['naranja']
# 🔗 Token base: 'beige' → ['beige']
# 🔗 Token base: 'mineralweiss' → ['mineralweiss']
# 🔗 Token base: 'summit' → ['summit']
# 🔗 Token base: 'violeta' → ['violeta']
# 🔗 Token base: 'cafe' → ['cafe']
# 🔗 Token base: 'bordo' → ['bordo']
# 🔗 Token base: 'otro' → ['otro']
# 🔗 Token base: 'prata' → ['prata']
# 🔗 Token base: 'blue' → ['blue']
# 🔗 Token base: 'steelblue' → ['steelblue']
# 🔗 Token base: 'acero' → ['acero']
# 🔗 Token base: 'rosa' → ['rosa']
# 🔗 Token base: 'carbon' → ['carbon']
# 🔗 Token base: 'skyscraper' → ['skyscraper']
# 🔗 Token base: 'grafito' → ['grafito']
#
# ✅ Total de colores imputados por contexto: 75
#
# 📚 Aprendiendo colores limpios desde df_train...
#
# [TOTAL] Muestras eliminadas en total: 180

# %%
val = df_to_numeric(train, val)
val.to_csv('data/numeric/val_numeric.csv', index=False)
test = df_to_numeric(train, test)
test.to_csv('data/numeric/test_numeric.csv', index=False)
train = df_to_numeric(train, train)
train.to_csv('data/numeric/train_numeric.csv', index=False)
# Out:
# df_to_input - No quedan columnas no numéricas.
# df_to_input - No quedan columnas no numéricas.
# df_to_input - No quedan columnas no numéricas.
